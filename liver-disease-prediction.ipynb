# %% [markdown]
# # ***Importing Libraries***

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import numpy as np
import cv2
import glob
import yaml
import torchvision
from torch.optim.lr_scheduler import ReduceLROnPlateau
import gc

# %% [markdown]
# # ***Loading Dataset***

# %%
dataset_path = '/kaggle/input/liver-disease-dataset'
data_yaml_path = os.path.join(dataset_path, 'dataset', 'data.yaml')  # Corrected path
dataset_root = os.path.join(dataset_path, 'dataset')

# Extract information from data.yaml, handling missing keys
train_images_folder = os.path.join(dataset_root, "images", "train")
train_labels_folder = os.path.join(dataset_root, "labels", "train")
val_images_folder = os.path.join(dataset_root, "images", "val")
val_labels_folder = os.path.join(dataset_root, "labels", "val")
test_images_folder = os.path.join(dataset_root, "images", "test")
test_labels_folder = os.path.join(dataset_root, "labels", "test")
data_yaml = os.path.join(dataset_root, "data.yaml")

# Set hyperparameters
batch_size = 4  # Reduced from 8
img_size = 416  # Reduced from 640
gradient_accumulation_steps = 2

# CUDA check
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:512'
torch.backends.cudnn.benchmark = True

# %% [markdown]
# # ***Residue Block***

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential() if in_channels == out_channels and stride == 1 else \
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride)

    def forward(self, x):
        identity = self.shortcut(x)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += identity
        out = self.relu(out)
        return out

# %% [markdown]
# # ***Stable Loss***

# %%
class StableLoss(nn.Module):
    def __init__(self, num_classes):
        super(StableLoss, self).__init__()
        self.num_classes = num_classes
        self.mse = nn.MSELoss(reduction='mean')
        self.bce = nn.BCEWithLogitsLoss(reduction='mean')
        self.entropy = nn.CrossEntropyLoss(reduction='mean')
    
    def forward(self, predictions, targets):
        # Verify shapes match
        if predictions.shape != targets.shape:
            raise ValueError(f"Shape mismatch: predictions {predictions.shape} vs targets {targets.shape}")
        
        # Extract target components
        obj_mask = targets[..., 4] > 0
        noobj_mask = targets[..., 4] == 0
        
        # No object loss
        noobj_loss = self.bce(
            predictions[..., 4][noobj_mask],
            targets[..., 4][noobj_mask]
        )
        
        if obj_mask.sum() > 0:
            # Box coordinates loss
            box_loss = self.mse(
                predictions[..., :4][obj_mask],
                targets[..., :4][obj_mask]
            )
            
            # Objectness loss
            obj_loss = self.bce(
                predictions[..., 4][obj_mask],
                targets[..., 4][obj_mask]
            )
            
            # Class prediction loss
            class_loss = self.entropy(
                predictions[..., 5:][obj_mask],
                targets[..., 5][obj_mask].long()
            )
            
            # Combine losses with weights
            total_loss = (
                box_loss * 1.0 +
                obj_loss * 1.0 +
                noobj_loss * 0.5 +
                class_loss * 1.0
            )
        else:
            total_loss = noobj_loss
        
        return total_loss

# %% [markdown]
# # ***YOLOv5 Class***

# %%
class ImprovedYOLOv5(nn.Module):
    def __init__(self, num_classes):
        super(ImprovedYOLOv5, self).__init__()
        self.num_classes = num_classes

        # Backbone
        self.backbone = nn.Sequential(
            ResidualBlock(3, 32, stride=2), # 208x208
            ResidualBlock(32, 64),
            nn.MaxPool2d(2), # 104x104
            ResidualBlock(64, 128),
            ResidualBlock(128, 256),
            nn.MaxPool2d(2), # 52x52
            ResidualBlock(256, 512),
            ResidualBlock(512, 1024),
        )

        # Neck
        self.neck = nn.Sequential(
            nn.Conv2d(1024, 512, kernel_size=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True)
        )

        # Detection head
        self.head = nn.Sequential(
            nn.Conv2d(512, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, (num_classes + 5), kernel_size=1) # 5 = (x,y,w,h,obj)
        )

    def forward(self, x):
        x = self.backbone(x)
        x = self.neck(x)
        x = self.head(x)

        # Reshape output to [batch_size, grid_size*grid_size, num_classes + 5]
        batch_size, channels, height, width = x.shape
        x = x.permute(0, 2, 3, 1).contiguous()
        x = x.view(batch_size, height * width, channels)

        return x, (height, width)  # Return grid dimensions too

# %% [markdown]
# # ***Custom Dataset***

# %%
class ImprovedCustomDataset(Dataset):
    def __init__(self, images_folder, labels_folder, img_size=640, augment=False):
        self.images_folder = images_folder
        self.labels_folder = labels_folder
        self.img_size = img_size
        self.augment = augment

        self.image_paths = sorted(
            glob.glob(os.path.join(images_folder, '*.jpg')) +
            glob.glob(os.path.join(images_folder, '*.jpeg')) +
            glob.glob(os.path.join(images_folder, '*.png'))
        )
        print(f"Found {len(self.image_paths)} images in {images_folder}")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = self._load_image(image_path)
        
        image_filename = os.path.basename(image_path)
        label_filename = os.path.splitext(image_filename)[0] + '.txt'
        label_path = os.path.join(self.labels_folder, label_filename)
        
        label = self._load_label(label_path)
        
        if self.augment:
            image, label = self._augment_data(image, label)
        
        return image, label

    def _load_image(self, image_path):
        try:
            image = cv2.imread(image_path)
            image = cv2.resize(image, (self.img_size, self.img_size))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = image.astype(np.float32) / 255.0
            image = np.transpose(image, (2, 0, 1))
            return torch.tensor(image).float()
        except Exception as e:
            print(f"Error loading image {image_path}: {e}")
            return torch.zeros((3, self.img_size, self.img_size))

    def _load_label(self, label_path):
        try:
            if os.path.exists(label_path) and os.path.getsize(label_path) > 0:
                labels = np.loadtxt(label_path, delimiter=' ', ndmin=2)
                if labels.size > 0:
                    return torch.tensor(labels).float()
            return torch.zeros((0, 5))
        except Exception as e:
            print(f"Warning: Error loading label {label_path}: {str(e)}")
            return torch.zeros((0, 5))

    def _augment_data(self, image, label):
        if np.random.random() < 0.5:
            image = torch.flip(image, [2])
            if label.size(0) > 0:
                label[:, 1] = 1 - label[:, 1]
        return image, label

# %%
def collate_fn(batch):
    images = []
    labels = []
    for img, label in batch:
        if img is not None:
            images.append(img)
            labels.append(label)
    if len(images) > 0:
        images = torch.stack(images, dim=0)
        labels = labels  # Keep labels as a list of tensors
        return images, labels
    else:
        return None, None

# %%
def prepare_targets(target_list, device, num_classes, grid_size):
    batch_size = len(target_list)
    grid_height, grid_width = grid_size
    total_grid_cells = grid_height * grid_width
    
    target_tensor = torch.zeros((batch_size, total_grid_cells, num_classes + 5), device=device)

    for batch_index, targets in enumerate(target_list):
        if targets.numel() == 0:
            continue

        for target in targets:
            class_index = int(target[0])
            x_center, y_center, width, height = target[1:5]

            # Scale x,y to grid dimensions
            i = int(x_center * grid_width)
            j = int(y_center * grid_height)
            
            # Bound check to prevent index errors
            i = min(max(i, 0), grid_width - 1)
            j = min(max(j, 0), grid_height - 1)

            one_hot = torch.zeros(num_classes, device=device)
            one_hot[class_index] = 1.0

            x_cell = x_center * grid_width - i
            y_cell = y_center * grid_height - j

            index = j * grid_width + i
            target_tensor[batch_index, index, 0:4] = torch.tensor([x_cell, y_cell, width, height], device=device)
            target_tensor[batch_index, index, 4] = 1.0
            target_tensor[batch_index, index, 5:] = one_hot

    return target_tensor

# %%
import math

def calculate_metrics(predictions, targets, iou_threshold=0.5):
    """
    Calculate object detection metrics.
    
    Args:
        predictions: Model predictions in format [batch_size, grid_cells, 5+num_classes]
        targets: Ground truth targets in same format
        iou_threshold: IoU threshold to consider detection as correct
        
    Returns:
        Dictionary of metrics including accuracy, precision, recall, F1 score
    """
    batch_size = predictions.size(0)
    metrics = {
        'accuracy': 0.0,
        'precision': 0.0,
        'recall': 0.0,
        'f1_score': 0.0
    }
    
    total_tp = 0
    total_fp = 0
    total_fn = 0
    
    for i in range(batch_size):
        # Apply sigmoid to objectness and softmax to class predictions
        pred_objectness = torch.sigmoid(predictions[i, :, 4])
        pred_classes = torch.softmax(predictions[i, :, 5:], dim=1)
        
        # Get objectness mask from targets (ground truth)
        target_obj_mask = targets[i, :, 4] > 0.5
        
        # If there are no objects in this image, skip
        if not target_obj_mask.any():
            continue
            
        # Count how many grid cells have objects (true positives + false negatives)
        num_gt_objects = target_obj_mask.sum().item()
        
        # Count predictions with objectness > 0.5 (true positives + false positives)
        pred_obj_mask = pred_objectness > 0.5
        num_pred_objects = pred_obj_mask.sum().item()
        
        # Count correct object detections (objectness and position)
        # This is a simplified accuracy measure
        correct_obj = (pred_obj_mask & target_obj_mask).sum().item()
        
        # Calculate metrics for this image
        tp = correct_obj
        fp = num_pred_objects - tp
        fn = num_gt_objects - tp
        
        # Accumulate for batch metrics
        total_tp += tp
        total_fp += fp
        total_fn += fn
        
        # Image accuracy = percentage of grid cells correctly classified
        batch_accuracy = correct_obj / max(1, num_gt_objects)
        metrics['accuracy'] += batch_accuracy
    
    # Calculate batch-level metrics
    metrics['accuracy'] /= batch_size
    
    # Precision = TP / (TP + FP)
    metrics['precision'] = total_tp / max(1, total_tp + total_fp)
    
    # Recall = TP / (TP + FN)
    metrics['recall'] = total_tp / max(1, total_tp + total_fn)
    
    # F1 score = 2 * Precision * Recall / (Precision + Recall)
    if metrics['precision'] + metrics['recall'] > 0:
        metrics['f1_score'] = 2 * metrics['precision'] * metrics['recall'] / (metrics['precision'] + metrics['recall'])
    
    return metrics

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device):
    best_val_loss = float('inf')
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_metrics = {'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0}
        optimizer.zero_grad()
        
        # Track batches for gradient accumulation
        valid_batches = 0
        
        for batch_idx, (batch_images, batch_targets) in enumerate(train_loader):
            if batch_images is None:
                continue
            
            try:
                batch_images = batch_images.to(device)
                
                # Get both outputs and grid size
                outputs, grid_size = model(batch_images)
                
                # Use the actual grid size from the model
                prepared_targets = prepare_targets(batch_targets, device, model.num_classes, grid_size)
                
                loss = criterion(outputs, prepared_targets)
                
                # Calculate metrics
                batch_metrics = calculate_metrics(outputs, prepared_targets)
                for key in train_metrics:
                    train_metrics[key] += batch_metrics.get(key, 0.0)
                
                # Normalize loss by gradient accumulation steps
                loss = loss / gradient_accumulation_steps
                loss.backward()
                
                if (batch_idx + 1) % gradient_accumulation_steps == 0:
                    # Gradient clipping to prevent explosion
                    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
                    optimizer.step()
                    optimizer.zero_grad()
                
                train_loss += loss.item() * gradient_accumulation_steps
                valid_batches += 1
                
                # Print progress
                if batch_idx % 20 == 0:
                    print(f'Train Epoch: {epoch+1} [{batch_idx}/{len(train_loader)}] Loss: {loss.item():.4f}')
                
                # Clean up GPU memory
                del outputs, loss, batch_images, prepared_targets
                torch.cuda.empty_cache()
            
            except RuntimeError as e:
                if "out of memory" in str(e):
                    print(f"WARNING: out of memory on batch {batch_idx}. Skipping...")
                    if torch.cuda.is_available():
                        torch.cuda.empty_cache()
                    continue
                else:
                    print(f"Error in batch {batch_idx}: {str(e)}")
                    raise e
        
        # Validation phase
        model.eval()
        val_loss = 0.0
        val_metrics = {'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0, 'f1_score': 0.0}
        valid_val_batches = 0
        
        with torch.no_grad():
            for val_images, val_targets in val_loader:
                if val_images is None:
                    continue
                
                try:
                    val_images = val_images.to(device)
                    
                    # Get both outputs and grid size
                    val_outputs, val_grid_size = model(val_images)
                    
                    # Use the actual grid size from the model
                    prepared_val_targets = prepare_targets(val_targets, device, model.num_classes, val_grid_size)
                    
                    val_batch_loss = criterion(val_outputs, prepared_val_targets)
                    val_loss += val_batch_loss.item()
                    
                    # Calculate validation metrics
                    batch_val_metrics = calculate_metrics(val_outputs, prepared_val_targets)
                    for key in val_metrics:
                        val_metrics[key] += batch_val_metrics.get(key, 0.0)
                    
                    valid_val_batches += 1
                    
                    # Clean up GPU memory
                    del val_outputs, val_batch_loss, val_images, prepared_val_targets
                    torch.cuda.empty_cache()
                
                except RuntimeError as e:
                    if "out of memory" in str(e):
                        print("WARNING: out of memory during validation. Skipping batch...")
                        if torch.cuda.is_available():
                            torch.cuda.empty_cache()
                        continue
                    else:
                        print(f"Error in validation: {str(e)}")
                        raise e

        # Calculate epoch metrics
        avg_train_loss = train_loss / max(1, valid_batches)
        avg_val_loss = val_loss / max(1, valid_val_batches)
        
        # Average the metrics
        for key in train_metrics:
            train_metrics[key] /= max(1, valid_batches)
            val_metrics[key] /= max(1, valid_val_batches)
        
        # Print epoch results
        print(f'Epoch {epoch+1}/{num_epochs}')
        print(f'Train Loss: {avg_train_loss:.4f}, Acc: {train_metrics["accuracy"]:.4f}, P: {train_metrics["precision"]:.4f}, R: {train_metrics["recall"]:.4f}, F1: {train_metrics["f1_score"]:.4f}')
        print(f'Val Loss: {avg_val_loss:.4f}, Acc: {val_metrics["accuracy"]:.4f}, P: {val_metrics["precision"]:.4f}, R: {val_metrics["recall"]:.4f}, F1: {val_metrics["f1_score"]:.4f}')
        
        # Update learning rate based on validation loss
        scheduler.step(avg_val_loss)
        
        # Clean up memory
        gc.collect()
        torch.cuda.empty_cache()
        
        # Save best model
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            print(f"Saving best model with val_loss: {best_val_loss:.4f}")
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': best_val_loss,
                'metrics': val_metrics
            }, 'best_liver_disease_model.pth')
        
    return model

# %%
def predict_disease(model, image_path, device, img_size=416, confidence_threshold=0.5):
    """
    Predict liver disease from image.

    Args:
        model: Trained model
        image_path: Path to the liver image
        device: Device to run inference on
        img_size: Input image size
        confidence_threshold: Threshold for detection confidence

    Returns:
        List of detections with disease class, confidence, and bounding box
    """
    # Load and preprocess image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Could not load image from {image_path}")
        return []

    original_h, original_w = image.shape[:2]
    image = cv2.resize(image, (img_size, img_size))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = image.astype(np.float32) / 255.0
    image = np.transpose(image, (2, 0, 1))
    image_tensor = torch.tensor(image).float().unsqueeze(0).to(device)

    # Run inference
    model.eval()
    with torch.no_grad():
        predictions, grid_size = model(image_tensor)

    # Convert predictions to boxes
    raw_detections = extract_boxes(predictions[0], confidence_threshold)

    # Convert to output format with class names
    class_names = ['healthy', 'fatty_liver', 'cirrhosis', 'hepatitis']

    detections = []
    for det in raw_detections:
        x1, y1, x2, y2 = det['bbox']
        class_id = det['class_id']
        confidence = det['confidence'] * det['class_prob']  # Combined confidence

        # Convert normalized coordinates to image coordinates
        x1_img = x1 * original_w
        y1_img = y1 * original_h
        x2_img = x2 * original_w
        y2_img = y2 * original_h

        detections.append({
            'disease': class_names[class_id],
            'class_id': class_id,  # Include class_id
            'confidence': confidence,
            'bbox': [x1_img, y1_img, x2_img, y2_img]
        })

    return detections

# %%
def extract_boxes(grid_predictions, confidence_threshold=0.5):
    """
    Convert grid cell predictions to bounding boxes.

    Args:
        grid_predictions: Tensor of shape [grid_cells, 5+num_classes]
        confidence_threshold: Minimum confidence to keep a detection

    Returns:
        List of dictionaries with format:
        {
            'box': [x1, y1, x2, y2],  # normalized 0-1 coordinates
            'confidence': float,       # objectness score
            'class_id': int,           # predicted class ID
            'class_prob': float        # class probability
        }
    """
    grid_cells = grid_predictions.size(0)
    grid_size = int(math.sqrt(grid_cells))
    num_classes = grid_predictions.size(1) - 5

    # Apply sigmoid to objectness
    objectness = torch.sigmoid(grid_predictions[:, 4])
    confident_mask = objectness > confidence_threshold

    if not confident_mask.any():
        return []

    confident_indices = confident_mask.nonzero(as_tuple=True)[0]
    grid_y = torch.div(confident_indices, grid_size, rounding_mode='floor')
    grid_x = confident_indices % grid_size

    confident_preds = grid_predictions[confident_indices]

    x_center = (torch.sigmoid(confident_preds[:, 0]) + grid_x) / grid_size
    y_center = (torch.sigmoid(confident_preds[:, 1]) + grid_y) / grid_size
    w = torch.exp(confident_preds[:, 2])  # Apply exponential to width
    h = torch.exp(confident_preds[:, 3])  # Apply exponential to height

    x1 = torch.clamp(x_center - w/2, 0, 1)
    y1 = torch.clamp(y_center - h/2, 0, 1)
    x2 = torch.clamp(x_center + w/2, 0, 1)
    y2 = torch.clamp(y_center + h/2, 0, 1)

    class_probs = torch.softmax(confident_preds[:, 5:], dim=1)
    class_ids = torch.argmax(class_probs, dim=1)
    max_class_probs = torch.max(class_probs, dim=1)[0]

    detections = []
    for i in range(len(confident_indices)):
        if w[i] * h[i] > 0:
            detections.append({
                'bbox': [x1[i].item(), y1[i].item(), x2[i].item(), y2[i].item()],
                'confidence': objectness[confident_indices[i]].item(),
                'class_id': class_ids[i].item(),
                'class_prob': max_class_probs[i].item()
            })

    return detections

# %%
def enhanced_visualize_prediction(image_path, detections, save_path=None, annotate_healthy=False):
    """
    Enhanced visualization of liver disease detections with medical-style annotations,
    severity heatmap overlays, and detailed lesion characteristics.
    Only annotates regions with disease, skipping healthy regions to avoid clutter.

    Args:
        image_path: Path to the original image
        detections: List of detection dictionaries
        save_path: Optional path to save the visualization
        annotate_healthy: If False, healthy regions won't be annotated
    """
    import cv2
    import numpy as np
    import matplotlib.pyplot as plt
    from matplotlib.patches import Rectangle, Circle, Arrow, FancyArrowPatch
    from matplotlib.colors import LinearSegmentedColormap

    # Read image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Could not load image from {image_path}")
        return

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    h, w = image.shape[:2]

    # Create figure with multiple subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 10))

    # Original image with basic annotations
    ax1.imshow(image)
    ax1.set_title('Original Image with Detections', fontsize=14)
    ax1.axis('off')

    # Enhanced visualization with medical annotations
    ax2.imshow(image)
    ax2.set_title('Medical Annotation View', fontsize=14)
    ax2.axis('off')

    # Create transparent overlay for heatmap
    overlay = np.zeros((h, w, 4), dtype=np.uint8)

    # Disease specific colors and markers (using medical convention)
    disease_info = {
        'fatty_liver': {
            'color': (255, 223, 0),  # Yellow
            'overlay_color': (255, 223, 0, 120),  # Semi-transparent yellow
            'marker': 'o',  # Circle
            'description': 'Increased echogenicity, vessel blurring',
            'severity_factor': 0.6  # Relative clinical severity
        },
        'cirrhosis': {
            'color': (255, 0, 85),  # Magenta-red
            'overlay_color': (255, 0, 85, 150),  # Semi-transparent magenta
            'marker': 's',  # Square
            'description': 'Nodular surface, parenchymal heterogeneity',
            'severity_factor': 0.9  # Higher severity
        },
        'hepatitis': {
            'color': (0, 191, 255),  # Blue
            'overlay_color': (0, 191, 255, 100),  # Semi-transparent blue
            'marker': '^',  # Triangle
            'description': 'Thickened portal tracts, parenchymal edema',
            'severity_factor': 0.75  # Moderate severity
        },
        'healthy': {
            'color': (0, 255, 0),  # Green
            'overlay_color': (0, 255, 0, 50),  # Very light green
            'marker': '+',  # Plus
            'description': 'Normal liver parenchyma',
            'severity_factor': 0  # No severity
        }
    }

    # Create a legend dictionary to avoid duplicate entries
    legend_elements = []
    seen_diseases = set()

    # Track highest confidence detection for the summary
    highest_conf_detection = None
    highest_conf = 0

    if detections:
        for i, detection in enumerate(detections):
            disease = detection['disease']
            confidence = detection['confidence']
            
            # Skip healthy regions to reduce clutter if annotate_healthy is False
            if disease == 'healthy' and not annotate_healthy:
                continue
                
            x1, y1, x2, y2 = [int(coord) for coord in detection['bbox']]

            # Track highest confidence detection
            if confidence > highest_conf:
                highest_conf = confidence
                highest_conf_detection = detection

            # Get disease-specific visualization attributes
            info = disease_info.get(disease, disease_info['healthy'])
            color_rgb = info['color']
            color = tuple(c/255 for c in color_rgb)  # Normalize for matplotlib

            # Center coordinates
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            width = x2 - x1
            height = y2 - y1

            # Basic annotation in first subplot
            rect = Rectangle((x1, y1), width, height,
                            linewidth=2, edgecolor=color, facecolor='none', alpha=0.7)
            ax1.add_patch(rect)

            # Add label with confidence
            ax1.text(x1, y1-10, f"{disease}: {confidence:.2f}",
                    color=color, fontsize=10, fontweight='bold',
                    bbox=dict(facecolor='white', alpha=0.7, edgecolor='none', pad=1))

            # Advanced medical annotations in second subplot
            # Calculate radius based on detection size and confidence
            radius = min(width, height) * 0.2 * (0.5 + confidence/2)

            # Draw ROI (Region of Interest) circle
            roi_circle = Circle((center_x, center_y), radius,
                               fill=False, edgecolor=color, linestyle='--', linewidth=2)
            ax2.add_patch(roi_circle)

            # Add measurement lines (typical in medical imaging)
            # Horizontal diameter line
            ax2.plot([center_x-width//3, center_x+width//3], [center_y, center_y],
                    color=color, linestyle='-', linewidth=1.5)
            # Label the measurement
            ax2.text(center_x, center_y+5, f"{width//3*2}px",
                    color=color, fontsize=8, ha='center')

            # Add medical annotation arrow and label
            arrow = FancyArrowPatch((center_x+radius+10, center_y), (center_x+radius+50, center_y),
                                   color=color, arrowstyle='->', linewidth=1.5)
            ax2.add_patch(arrow)

            # Clinical description label
            label_text = f"{disease} ({confidence:.2f})\n{info['description']}"
            ax2.text(center_x+radius+55, center_y, label_text,
                    color=color, fontsize=9, va='center',
                    bbox=dict(facecolor='white', alpha=0.8, boxstyle='round,pad=0.5'))

            # Create a gaussian-like heatmap around the detection center
            y_grid, x_grid = np.ogrid[:h, :w]
            # Distance from center with elliptical weighting to match ROI shape
            dist_from_center = np.sqrt(
                ((x_grid - center_x) / (width/2)) ** 2 +
                ((y_grid - center_y) / (height/2)) ** 2
            )

            # Create intensity mask that decreases with distance
            intensity = np.exp(-0.5 * dist_from_center**2) * confidence * info['severity_factor']
            intensity = np.clip(intensity, 0, 1)

            # Create colored overlay based on intensity
            for c in range(3):
                channel_intensity = intensity * info['overlay_color'][c]
                # Add color overlay with alpha proportional to intensity
                overlay[:,:,c] = np.maximum(
                    overlay[:,:,c],
                    channel_intensity.astype(np.uint8)
                )

            # Alpha channel based on intensity
            overlay[:,:,3] = np.maximum(
                overlay[:,:,3],
                (intensity * info['overlay_color'][3]).astype(np.uint8)
            )

            # Add to legend if not already added
            if disease not in seen_diseases:
                from matplotlib.lines import Line2D
                legend_elements.append(
                    Line2D([0], [0], marker=info['marker'], color='w',
                          markerfacecolor=color, markersize=10, label=disease)
                )
                seen_diseases.add(disease)

    # Add the heatmap overlay to the second subplot
    ax2.imshow(overlay, alpha=0.5)

    # Add legend to second subplot
    if legend_elements:
        ax2.legend(handles=legend_elements, loc='lower right', fontsize=10)

    # Display clinical summary box
    if highest_conf_detection:
        disease = highest_conf_detection['disease']
        confidence = highest_conf_detection['confidence']

        summary_text = (
            f"DIAGNOSIS SUMMARY:\n"
            f"Primary finding: {disease.replace('_', ' ').title()} (conf: {confidence:.2f})\n"
            f"Recommendation: {'Further testing required' if confidence < 0.8 else 'Diagnosis confirmed'}\n"
            f"Detected lesions: {len([d for d in detections if d['disease'] != 'healthy' or annotate_healthy])}\n"
            f"Image quality: {'Adequate for diagnosis' if confidence > 0.6 else 'Suboptimal'}"
        )

        # Add a clinical summary box
        props = dict(boxstyle='round,pad=0.5', facecolor='white', alpha=0.8)
        fig.text(0.5, 0.03, summary_text, fontsize=12,
                bbox=props, ha='center', va='center')

    plt.tight_layout()

    # Add a main title above both subplots
    plt.suptitle('Liver Disease Detection - Advanced Medical Visualization', fontsize=16, y=0.98)

    # Move subplots up to make room for summary
    plt.subplots_adjust(bottom=0.15)

    # Save if path provided
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Visualization saved to {save_path}")

    plt.show()


def generate_medical_report(image_path, detections, patient_id="Unknown"):
    """
    Generate a structured medical report based on the detections.
    
    Args:
        image_path: Path to the analyzed image
        detections: List of detection dictionaries 
        patient_id: Optional patient identifier
    
    Returns:
        A formatted string containing the medical report
    """
    import datetime
    
    # Get current date for the report
    current_date = datetime.datetime.now().strftime("%B %d, %Y")
    
    # Count detections by type
    disease_counts = {}
    disease_confidences = {}
    
    for detection in detections:
        disease = detection['disease']
        confidence = detection['confidence']
        
        if disease not in disease_counts:
            disease_counts[disease] = 0
            disease_confidences[disease] = []
            
        disease_counts[disease] += 1
        disease_confidences[disease].append(confidence)
    
    # Get primary diagnosis (highest confidence)
    primary_diagnosis = "No abnormalities detected"
    primary_confidence = 0
    
    for disease, confidences in disease_confidences.items():
        avg_confidence = sum(confidences) / len(confidences)
        if avg_confidence > primary_confidence and disease != 'healthy':
            primary_diagnosis = disease
            primary_confidence = avg_confidence
    
    # Disease-specific descriptions
    disease_descriptions = {
        'fatty_liver': "Liver shows increased echogenicity consistent with fatty infiltration. "
                      "Hepatic vessels appear less prominent with reduced contrast. "
                      "Findings are consistent with hepatic steatosis.",
        
        'cirrhosis': "Liver demonstrates nodular surface and heterogeneous parenchyma. "
                    "Contour irregularity and volume redistribution are noted. "
                    "Findings are consistent with cirrhotic changes.",
        
        'hepatitis': "Liver shows mild to moderate parenchymal heterogeneity with periportal edema. "
                    "Subtle enhancement of periportal regions noted. "
                    "Findings are suggestive of inflammatory changes.",
        
        'healthy': "Liver parenchyma shows normal echogenicity and homogeneous texture. "
                  "Normal visualization of intrahepatic vessels. "
                  "No focal lesions or parenchymal abnormalities detected."
    }
    
    # Generate report
    report = f"""
{"="*80}
                    LIVER IMAGING REPORT
{"="*80}

PATIENT ID: {patient_id}
EXAMINATION DATE: {current_date}
IMAGE ANALYZED: {image_path.split('/')[-1]}

{"="*80}
FINDINGS:
{"="*80}

"""
    
    # Add detected abnormalities
    if detections:
        if 'healthy' in disease_counts and len(disease_counts) == 1:
            report += "No significant abnormalities detected in the liver parenchyma.\n"
            report += disease_descriptions['healthy']
        else:
            for disease, count in disease_counts.items():
                if disease == 'healthy':
                    continue
                    
                avg_conf = sum(disease_confidences[disease]) / len(disease_confidences[disease])
                report += f"\n{disease.replace('_', ' ').upper()}:\n"
                report += f"- Detected {count} region(s) with average confidence score of {avg_conf:.2f}\n"
                report += f"- {disease_descriptions.get(disease, 'No description available.')}\n"
    else:
        report += "No significant findings detected in this image.\n"
    
    # Add impression section
    report += f"""
{"="*80}
IMPRESSION:
{"="*80}

"""
    
    if primary_diagnosis != "No abnormalities detected":
        confidence_level = "high" if primary_confidence > 0.8 else "moderate" if primary_confidence > 0.6 else "low"
        report += f"1. {primary_diagnosis.replace('_', ' ').upper()} with {confidence_level} confidence ({primary_confidence:.2f})\n"
        
        # Add secondary findings
        secondary_count = 2
        for disease, confidences in disease_confidences.items():
            avg_conf = sum(confidences) / len(confidences)
            if disease != primary_diagnosis and disease != 'healthy' and avg_conf > 0.4:
                report += f"{secondary_count}. {disease.replace('_', ' ').upper()} with lower confidence ({avg_conf:.2f})\n"
                secondary_count += 1
    else:
        report += "No significant liver abnormalities detected in this examination.\n"
    
    # Add recommendations
    report += f"""
{"="*80}
RECOMMENDATIONS:
{"="*80}

"""
    
    if primary_diagnosis == 'fatty_liver':
        report += "1. Recommend clinical correlation with liver function tests.\n"
        report += "2. Consider dietary modifications and weight management if appropriate.\n"
        report += "3. Follow-up imaging in 6 months to assess progression.\n"
    elif primary_diagnosis == 'cirrhosis':
        report += "1. Urgent clinical assessment of liver function is recommended.\n"
        report += "2. Consider gastroenterology referral for management of cirrhosis.\n"
        report += "3. Evaluate for complications including portal hypertension and ascites.\n"
        report += "4. Recommend screening for hepatocellular carcinoma.\n"
    elif primary_diagnosis == 'hepatitis':
        report += "1. Correlate with serology for viral hepatitis markers.\n"
        report += "2. Consider liver biopsy for further characterization if clinically indicated.\n"
        report += "3. Follow-up imaging after clinical treatment course.\n"
    else:
        report += "No specific follow-up imaging required based on current findings.\n"
    
    # Signature
    report += f"""
{"="*80}

Report generated by AI Liver Analysis System
This is a computer-generated report and requires clinical correlation.
{"="*80}
"""
    
    return report

# %% [markdown]
# # ***Training***

# %%
# Instantiate Datasets
train_dataset = ImprovedCustomDataset(train_images_folder, train_labels_folder, img_size=img_size, augment=True)
val_dataset = ImprovedCustomDataset(val_images_folder, val_labels_folder, img_size=img_size, augment=False)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2, collate_fn=collate_fn)

# Model and Optimizer
model = ImprovedYOLOv5(num_classes=4).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
criterion = StableLoss(num_classes=4).to(device)
num_epochs = 25

# Train model
trained_model = train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device)
# Out:
# Found 2782 images in /kaggle/input/liver-disease-dataset/dataset/images/train
# Found 794 images in /kaggle/input/liver-disease-dataset/dataset/images/val
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Train Epoch: 1 [0/696] Loss: 1.5563
# Train Epoch: 1 [20/696] Loss: 0.5137
# Train Epoch: 1 [40/696] Loss: 0.5078
# Train Epoch: 1 [60/696] Loss: 0.5016
# Train Epoch: 1 [80/696] Loss: 0.5097
# Train Epoch: 1 [100/696] Loss: 0.3122
# Train Epoch: 1 [120/696] Loss: 0.6766
# Train Epoch: 1 [140/696] Loss: 0.7444
# Train Epoch: 1 [160/696] Loss: 0.2574
# Train Epoch: 1 [180/696] Loss: 0.3322
# Train Epoch: 1 [200/696] Loss: 0.3388
# Train Epoch: 1 [220/696] Loss: 0.4797
# Train Epoch: 1 [240/696] Loss: 0.3417
# Train Epoch: 1 [260/696] Loss: 0.6178
# Train Epoch: 1 [280/696] Loss: 0.2807
# Train Epoch: 1 [300/696] Loss: 0.4146
# Train Epoch: 1 [320/696] Loss: 0.5803
# Train Epoch: 1 [340/696] Loss: 0.5053
# Train Epoch: 1 [360/696] Loss: 0.3074
# Train Epoch: 1 [380/696] Loss: 0.2570
# Train Epoch: 1 [400/696] Loss: 0.3761
# Train Epoch: 1 [420/696] Loss: 0.2795
# Train Epoch: 1 [440/696] Loss: 0.2277
# Train Epoch: 1 [460/696] Loss: 0.2830
# Train Epoch: 1 [480/696] Loss: 0.2816
# Train Epoch: 1 [500/696] Loss: 0.3726
# Train Epoch: 1 [520/696] Loss: 0.5641
# Train Epoch: 1 [540/696] Loss: 0.2867
# Train Epoch: 1 [560/696] Loss: 0.2134
# Train Epoch: 1 [580/696] Loss: 0.4310
# Train Epoch: 1 [600/696] Loss: 0.3458
# Train Epoch: 1 [620/696] Loss: 0.3784
# Train Epoch: 1 [640/696] Loss: 0.2556
# Train Epoch: 1 [660/696] Loss: 1.0022
# Train Epoch: 1 [680/696] Loss: 0.2977
# Epoch 1/25
# Train Epoch: 25 [640/696] Loss: 0.1252
# Train Epoch: 25 [660/696] Loss: 0.2257
# Train Epoch: 25 [680/696] Loss: 0.1057
# Epoch 25/25
# Train Loss: 0.3078, Acc: 0.9669, P: 0.0079, R: 0.9739, F1: 0.0156
# Val Loss: 0.5531, Acc: 0.9493, P: 0.0064, R: 0.9554, F1: 0.0127

# %% [markdown]
# # ***Prediction***

# %%
import matplotlib.pyplot as plt
checkpoint = torch.load('best_liver_disease_model.pth')
model.load_state_dict(checkpoint['model_state_dict'])

# Predict on a new image
test_image_path = '/kaggle/input/testing/208_5_3_26_jpg.rf.a1ef0df7cde146acdcb08ff4a8a86c4e.jpg'
detections = predict_disease(model, test_image_path, device)

# Display results
for detection in detections:
    print(f"Detected {detection['disease']} with {detection['confidence']:.2f} confidence")
    print(f"Location: {detection['bbox']}")

enhanced_visualize_prediction(test_image_path, detections, save_path='liver_analysis_report.png')
# Generate and print a medical-style report
report = generate_medical_report(test_image_path, detections, patient_id="LIV-2025-001")
print(report)
# Out:
# <ipython-input-21-03a895a85420>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('best_liver_disease_model.pth')
# Detected healthy with 0.52 confidence
# Location: [0.0, 0.0, 299.0, 171.225865483284]
# Detected healthy with 0.86 confidence
# Location: [0.0, 0.0, 299.0, 172.91321462392807]
# Detected healthy with 0.75 confidence
# Location: [0.0, 0.0, 299.0, 170.9451544880867]
# Detected healthy with 0.79 confidence
# Location: [0.0, 0.0, 208.35713469982147, 179.01940500736237]
# Detected healthy with 0.92 confidence
# Location: [0.0, 0.0, 299.0, 172.09834897518158]
# Detected healthy with 0.97 confidence
# Location: [0.0, 0.0, 299.0, 174.6022211909294]
# Detected healthy with 0.96 confidence
# Location: [0.0, 0.0, 299.0, 178.59932762384415]
# Detected healthy with 0.78 confidence
# Location: [0.0, 0.0, 299.0, 182.58898454904556]
# Detected healthy with 0.80 confidence
# Location: [100.31127482652664, 0.0, 299.0, 171.3139407634735]
# Detected healthy with 0.99 confidence
# Location: [100.7786512374878, 0.0, 299.0, 175.7935008406639]
# Detected healthy with 0.96 confidence
# Location: [103.9728147983551, 0.0, 299.0, 177.72935700416565]
# Detected healthy with 0.98 confidence
# Location: [0.0, 0.0, 180.78381556272507, 184.24824655056]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 212.37429064512253, 179.8170548081398]
# Detected healthy with 0.95 confidence
# Location: [0.0, 0.0, 223.4209303855896, 186.21502351760864]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 274.0951729416847, 182.32518643140793]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 278.44160425662994, 180.15780740976334]
# Detected healthy with 0.55 confidence
# Location: [101.50098615884781, 0.0, 299.0, 175.50234627723694]
# Detected healthy with 0.95 confidence
# Location: [110.93238371610641, 0.0, 299.0, 171.3682081103325]
# Detected healthy with 0.81 confidence
# Location: [112.13829505443573, 0.0, 299.0, 183.62681859731674]
# Detected healthy with 0.70 confidence
# Location: [0.0, 0.0, 164.68942147493362, 189.64357924461365]
# Detected healthy with 0.98 confidence
# Location: [0.0, 0.0, 182.86178267002106, 192.59688133001328]
# Detected healthy with 0.93 confidence
# Location: [0.0, 0.0, 200.58849221467972, 176.8807190656662]
# Detected healthy with 0.59 confidence
# Location: [0.0, 0.0, 206.35720920562744, 185.19477957487106]
# Detected healthy with 0.98 confidence
# Location: [0.0, 0.0, 269.0960364341736, 182.27050918340683]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 278.7162380218506, 194.57508206367493]
# Detected healthy with 0.95 confidence
# Location: [0.0, 0.0, 185.40094202756882, 201.39540934562683]
# Detected healthy with 0.54 confidence
# Location: [73.24550241231918, 0.0, 299.0, 208.6968892812729]
# Detected healthy with 0.90 confidence
# Location: [0.0, 0.0, 299.0, 208.40920996665955]
# Detected healthy with 0.56 confidence
# Location: [0.0, 0.0, 299.0, 214.09127742052078]
# Detected healthy with 0.76 confidence
# Location: [74.89241391420364, 0.0, 299.0, 209.46399253606796]
# Detected healthy with 1.00 confidence
# Location: [72.4960070848465, 0.0, 299.0, 215.21456694602966]
# Detected healthy with 0.99 confidence
# Location: [82.03820270299911, 0.0, 299.0, 219.07013273239136]
# Detected healthy with 0.57 confidence
# Location: [134.31587159633636, 0.0, 299.0, 212.37920945882797]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 299.0, 217.63902527093887]
# Detected healthy with 1.00 confidence
# Location: [0.0, 0.0, 299.0, 222.1937398314476]
# Detected healthy with 0.97 confidence
# Location: [0.0, 0.0, 299.0, 223.24788081645966]
# Detected healthy with 0.70 confidence
# Location: [78.20658940076828, 0.0, 299.0, 215.00514310598373]
# Detected healthy with 0.99 confidence
# Location: [73.493492603302, 0.0, 299.0, 223.4284155368805]
# Detected healthy with 0.96 confidence
# Location: [79.25953632593155, 0.0, 299.0, 227.5793240070343]
# Detected healthy with 0.64 confidence
# Location: [120.0397098660469, 0.0, 299.0, 218.60986721515656]
# Detected healthy with 0.76 confidence
# Location: [129.8330501317978, 0.0, 299.0, 219.5177447795868]
# Detected healthy with 0.88 confidence
# Location: [0.0, 0.0, 299.0, 211.9291558265686]
# Detected healthy with 0.93 confidence
# Location: [0.0, 0.0, 299.0, 225.42536479234695]
# Detected healthy with 0.49 confidence
# Location: [87.74808996915817, 0.0, 299.0, 221.52902275323868]
# Detected fatty_liver with 0.44 confidence
# Location: [84.50112044811249, 0.0, 299.0, 230.87131136655807]
# Detected healthy with 0.86 confidence
# Location: [119.66883844137192, 0.0, 299.0, 225.8725134730339]
# Detected healthy with 0.81 confidence
# Location: [124.53812539577484, 0.0, 299.0, 228.68652045726776]
# Detected fatty_liver with 0.88 confidence
# Location: [73.76392042636871, 0.0, 299.0, 240.00225138664246]
# Detected fatty_liver with 0.59 confidence
# Location: [78.1913161277771, 0.0, 299.0, 247.820474088192]
# Detected healthy with 0.95 confidence
# Location: [114.95832580327988, 0.0, 299.0, 231.84315133094788]
# Detected healthy with 0.86 confidence
# Location: [122.92368519306183, 0.0, 299.0, 235.00543171167374]
# Detected healthy with 0.94 confidence
# Location: [118.1340081691742, 0.0, 299.0, 233.98401153087616]
# Detected healthy with 0.84 confidence
# Location: [124.94328594207764, 0.0, 299.0, 238.148357629776]
# Detected healthy with 0.53 confidence
# Location: [134.89723616838455, 0.0, 299.0, 229.9022337794304]
# Detected healthy with 0.74 confidence
# Location: [0.0, 0.0, 265.36101722717285, 259.91546273231506]
# Detected healthy with 0.61 confidence
# Location: [0.0, 0.0, 278.8636955022812, 262.5184240937233]
# Detected healthy with 0.96 confidence
# Location: [0.0, 0.0, 296.12869596481323, 243.34886252880096]
# Detected healthy with 0.58 confidence
# Location: [0.0, 0.0, 299.0, 247.24025011062622]
# Detected healthy with 0.95 confidence
# Location: [0.0, 0.0, 260.95108687877655, 263.75668197870255]
# Detected healthy with 1.00 confidence
# Location: [0.0, 0.0, 266.67483949661255, 267.98525780439377]
# Detected healthy with 1.00 confidence
# Location: [0.0, 0.0, 264.9622725248337, 267.034750521183]
# Detected healthy with 0.34 confidence
# Location: [0.0, 0.0, 287.4308432340622, 241.9443986415863]
# Detected healthy with 0.86 confidence
# Location: [0.0, 0.0, 286.73304891586304, 242.50676518678665]
# Detected healthy with 0.95 confidence
# Location: [0.0, 0.0, 299.0, 251.76349139213562]
# Detected healthy with 0.98 confidence
# Location: [2.9374406933784485, 0.0, 299.0, 257.82886987924576]
# Detected healthy with 0.88 confidence
# Location: [0.0, 0.0, 257.23654490709305, 266.1361937522888]
# Detected healthy with 1.00 confidence
# Location: [0.0, 0.0, 264.66913974285126, 272.2274672985077]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 264.86617743968964, 280.84672594070435]
# Detected healthy with 0.97 confidence
# Location: [0.0, 0.0, 299.0, 265.6008628606796]
# Detected healthy with 1.00 confidence
# Location: [0.0, 0.0, 299.0, 268.14052122831345]
# Detected healthy with 0.99 confidence
# Location: [3.35972797870636, 0.0, 299.0, 270.79320538043976]
# Detected healthy with 0.97 confidence
# Location: [0.0, 0.0, 299.0, 266.89415442943573]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 299.0, 274.1181808710098]
# Detected healthy with 0.91 confidence
# Location: [7.590994894504547, 0.0, 299.0, 281.8837401866913]
# Detected healthy with 0.88 confidence
# Location: [0.0, 0.0, 193.23438453674316, 286.5552943944931]
# Detected healthy with 0.64 confidence
# Location: [76.20502430200577, 0.0, 299.0, 279.2229292988777]
# Detected healthy with 0.84 confidence
# Location: [0.0, 0.0, 200.09475737810135, 299.0]
# Detected healthy with 0.75 confidence
# Location: [0.0, 0.0, 209.40539449453354, 299.0]
# Detected healthy with 0.71 confidence
# Location: [0.0, 0.0, 293.0859463214874, 283.71492898464203]
# Detected healthy with 0.86 confidence
# Location: [72.5688625574112, 0.0, 299.0, 282.5658869743347]
# Detected healthy with 0.95 confidence
# Location: [82.90762084722519, 0.0, 299.0, 280.5861535668373]
# Detected healthy with 0.85 confidence
# Location: [80.49658232927322, 0.0, 299.0, 283.6462081670761]
# Detected healthy with 0.88 confidence
# Location: [0.0, 0.0, 206.21884083747864, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 0.0, 212.58558577299118, 299.0]
# Detected healthy with 0.73 confidence
# Location: [75.20935660600662, 0.0, 299.0, 287.08365696668625]
# Detected healthy with 0.94 confidence
# Location: [82.91704857349396, 0.0, 299.0, 288.1348395347595]
# Detected healthy with 0.88 confidence
# Location: [74.490265250206, 0.0, 299.0, 295.32304418087006]
# Detected healthy with 0.54 confidence
# Location: [78.10206460952759, 0.0, 299.0, 299.0]
# Detected healthy with 0.92 confidence
# Location: [0.0, 0.0, 203.96028554439545, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 0.0, 211.86373203992844, 299.0]
# Detected healthy with 0.89 confidence
# Location: [115.02644068002701, 0.0, 299.0, 299.0]
# Detected healthy with 0.95 confidence
# Location: [0.0, 0.0, 201.94551450014114, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 212.57141745090485, 299.0]
# Detected healthy with 0.91 confidence
# Location: [110.46869641542435, 0.0, 299.0, 299.0]
# Detected healthy with 0.97 confidence
# Location: [113.28088557720184, 0.0, 299.0, 299.0]
# Detected healthy with 0.93 confidence
# Location: [0.0, 0.0, 201.5766212940216, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 0.0, 210.29956710338593, 299.0]
# Detected fatty_liver with 0.61 confidence
# Location: [24.8611102104187, 0.0, 299.0, 299.0]
# Detected healthy with 0.97 confidence
# Location: [109.87090015411377, 0.0, 299.0, 299.0]
# Detected healthy with 0.98 confidence
# Location: [110.154052734375, 0.0, 299.0, 299.0]
# Detected healthy with 0.87 confidence
# Location: [0.0, 0.0, 201.57578366994858, 299.0]
# Detected healthy with 0.79 confidence
# Location: [0.0, 0.0, 202.43905329704285, 299.0]
# Detected healthy with 0.65 confidence
# Location: [129.30794894695282, 0.0, 299.0, 299.0]
# Detected healthy with 0.57 confidence
# Location: [8.974642932415009, 0.0, 299.0, 299.0]
# Detected fatty_liver with 0.53 confidence
# Location: [0.0, 0.0, 299.0, 299.0]
# Detected healthy with 0.82 confidence
# Location: [5.240051448345184, 0.0, 299.0, 299.0]
# Detected healthy with 0.91 confidence
# Location: [7.697943449020386, 0.0, 299.0, 299.0]
# Detected fatty_liver with 0.42 confidence
# Location: [3.8394192457199097, 0.0, 299.0, 299.0]
# Detected fatty_liver with 0.70 confidence
# Location: [5.268120765686035, 0.0, 299.0, 299.0]
# Detected fatty_liver with 0.61 confidence
# Location: [2.048561155796051, 0.0, 299.0, 299.0]
# Detected healthy with 0.63 confidence
# Location: [70.85511934757233, 0.0, 299.0, 299.0]
# Detected healthy with 0.89 confidence
# Location: [7.317109644412994, 0.0, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [7.190343260765076, 0.0, 299.0, 299.0]
# Detected healthy with 0.95 confidence
# Location: [10.304184019565582, 0.0, 299.0, 299.0]
# Detected healthy with 0.40 confidence
# Location: [11.086115002632141, 0.0, 299.0, 299.0]
# Detected healthy with 0.93 confidence
# Location: [0.0, 0.0, 299.0, 299.0]
# Detected healthy with 0.74 confidence
# Location: [0.0, 0.0, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [5.544821858406067, 0.0, 299.0, 299.0]
# Detected healthy with 0.97 confidence
# Location: [8.654937863349915, 0.0, 299.0, 299.0]
# Detected healthy with 0.83 confidence
# Location: [0.0, 0.0, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 0.0, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 0.0, 299.0, 299.0]
# Detected healthy with 0.60 confidence
# Location: [109.88223481178284, 15.441136419773102, 299.0, 299.0]
# Detected healthy with 0.87 confidence
# Location: [120.31341689825058, 18.292979061603546, 299.0, 299.0]
# Detected healthy with 0.70 confidence
# Location: [127.11237585544586, 16.369776368141174, 299.0, 299.0]
# Detected healthy with 0.65 confidence
# Location: [0.0, 2.464575171470642, 299.0, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 0.0, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 0.0, 299.0, 299.0]
# Detected healthy with 0.74 confidence
# Location: [110.70030838251114, 19.599619150161743, 299.0, 299.0]
# Detected healthy with 0.91 confidence
# Location: [117.52241784334183, 19.448347806930542, 299.0, 299.0]
# Detected healthy with 0.77 confidence
# Location: [123.15155458450317, 18.128091871738434, 299.0, 299.0]
# Detected healthy with 0.90 confidence
# Location: [0.0, 22.523479640483856, 178.00420463085175, 299.0]
# Detected healthy with 0.51 confidence
# Location: [0.0, 14.675797522068024, 190.76503312587738, 299.0]
# Detected healthy with 0.59 confidence
# Location: [0.0, 22.40428751707077, 218.4425562620163, 299.0]
# Detected healthy with 0.63 confidence
# Location: [0.0, 11.844859838485718, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 24.14351588487625, 183.26148974895477, 299.0]
# Detected healthy with 0.93 confidence
# Location: [0.0, 16.71539431810379, 187.79059439897537, 299.0]
# Detected healthy with 0.96 confidence
# Location: [58.470401883125305, 24.815308213233948, 299.0, 299.0]
# Detected healthy with 0.82 confidence
# Location: [63.086868941783905, 26.016175985336304, 299.0, 299.0]
# Detected fatty_liver with 0.82 confidence
# Location: [61.48053765296936, 23.510218620300293, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 27.401392340660095, 184.57573974132538, 299.0]
# Detected healthy with 0.95 confidence
# Location: [0.0, 17.43630349636078, 187.519382417202, 299.0]
# Detected healthy with 0.93 confidence
# Location: [58.30622756481171, 27.196994245052338, 299.0, 299.0]
# Detected fatty_liver with 0.89 confidence
# Location: [57.595013439655304, 21.7293763756752, 299.0, 299.0]
# Detected fatty_liver with 0.97 confidence
# Location: [62.793148040771484, 19.686945915222168, 299.0, 299.0]
# Detected fatty_liver with 0.70 confidence
# Location: [63.565900802612305, 12.695012629032135, 299.0, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 32.778814136981964, 184.69104671478271, 299.0]
# Detected healthy with 0.88 confidence
# Location: [0.0, 22.306802332401276, 187.5533685684204, 299.0]
# Detected healthy with 0.53 confidence
# Location: [0.0, 29.785822927951813, 250.87323957681656, 299.0]
# Detected healthy with 0.60 confidence
# Location: [12.76474928855896, 44.99397510290146, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [17.63934713602066, 41.94062149524689, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [20.248563945293427, 39.00269961357117, 299.0, 299.0]
# Detected fatty_liver with 0.52 confidence
# Location: [68.09131634235382, 38.89580452442169, 299.0, 299.0]
# Detected fatty_liver with 0.62 confidence
# Location: [67.42667055130005, 31.109429359436035, 299.0, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 37.69124764204025, 184.16993761062622, 299.0]
# Detected healthy with 0.72 confidence
# Location: [0.0, 30.025953710079193, 186.37811070680618, 299.0]
# Detected healthy with 0.95 confidence
# Location: [0.0, 42.31411272287369, 234.71474051475525, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 36.663554191589355, 244.27898168563843, 299.0]
# Detected healthy with 0.86 confidence
# Location: [0.0, 36.68554627895355, 248.86094576120377, 299.0]
# Detected healthy with 0.93 confidence
# Location: [30.285171627998352, 55.550640404224396, 299.0, 299.0]
# Detected healthy with 0.90 confidence
# Location: [32.9996617436409, 44.84168791770935, 299.0, 299.0]
# Detected healthy with 0.77 confidence
# Location: [116.82925719022751, 43.98412126302719, 299.0, 299.0]
# Detected healthy with 0.84 confidence
# Location: [126.76611632108688, 40.86650228500366, 299.0, 299.0]
# Detected healthy with 0.95 confidence
# Location: [0.0, 43.81664991378784, 182.24001610279083, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 32.63139230012894, 240.80506950616837, 299.0]
# Detected healthy with 1.00 confidence
# Location: [0.0, 32.96148747205734, 241.82679265737534, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 30.42277365922928, 236.50800454616547, 299.0]
# Detected healthy with 0.93 confidence
# Location: [118.98907977342606, 46.90365105867386, 299.0, 299.0]
# Detected healthy with 0.92 confidence
# Location: [124.06007373332977, 44.77011561393738, 299.0, 299.0]
# Detected healthy with 0.93 confidence
# Location: [0.0, 49.694133281707764, 181.5303168296814, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 51.59864091873169, 234.98595249652863, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 37.193877160549164, 239.82633250951767, 299.0]
# Detected healthy with 0.67 confidence
# Location: [0.0, 58.12546116113663, 296.713036775589, 299.0]
# Detected healthy with 0.50 confidence
# Location: [0.0, 60.107083678245544, 299.0, 299.0]
# Detected healthy with 0.93 confidence
# Location: [119.27125215530396, 55.92341876029968, 299.0, 299.0]
# Detected healthy with 0.91 confidence
# Location: [123.56305968761444, 51.587359726428986, 299.0, 299.0]
# Detected healthy with 0.54 confidence
# Location: [0.0, 64.79870522022247, 150.89275497198105, 299.0]
# Detected healthy with 0.86 confidence
# Location: [0.0, 57.20542913675308, 181.5725366473198, 299.0]
# Detected healthy with 0.77 confidence
# Location: [0.0, 74.29609686136246, 276.4896550178528, 299.0]
# Detected healthy with 0.89 confidence
# Location: [0.0, 72.47873777151108, 283.4137051105499, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 82.17400473356247, 275.55511605739594, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 76.14246982336044, 286.4348191022873, 299.0]
# Detected healthy with 0.54 confidence
# Location: [0.0, 111.44469776749611, 152.72579723596573, 299.0]
# Detected healthy with 0.66 confidence
# Location: [0.0, 82.7195296883583, 299.0, 299.0]
# Detected healthy with 0.89 confidence
# Location: [0.0, 83.99343115091324, 299.0, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 83.6512171626091, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 82.02709972858429, 299.0, 299.0]
# Detected healthy with 0.95 confidence
# Location: [5.684633791446686, 81.7926897406578, 299.0, 299.0]
# Detected healthy with 0.61 confidence
# Location: [60.691887855529785, 86.63194698095322, 299.0, 299.0]
# Detected healthy with 0.96 confidence
# Location: [62.05463093519211, 81.1267786026001, 299.0, 299.0]
# Detected healthy with 0.97 confidence
# Location: [61.26851183176041, 84.86151266098022, 299.0, 299.0]
# Detected healthy with 0.98 confidence
# Location: [70.03387349843979, 84.24555599689484, 299.0, 299.0]
# Detected healthy with 0.87 confidence
# Location: [83.23657542467117, 82.69391977787018, 299.0, 299.0]
# Detected healthy with 0.52 confidence
# Location: [0.0, 99.46573787927628, 204.54532140493393, 299.0]
# Detected healthy with 0.80 confidence
# Location: [0.0, 98.55782467126846, 216.60830211639404, 299.0]
# Detected healthy with 0.89 confidence
# Location: [0.0, 95.0597283244133, 225.5418123602867, 299.0]
# Detected healthy with 0.88 confidence
# Location: [0.0, 94.28492605686188, 234.01976203918457, 299.0]
# Detected healthy with 0.89 confidence
# Location: [0.0, 95.67876815795898, 237.86263871192932, 299.0]
# Detected healthy with 0.90 confidence
# Location: [0.0, 98.01222842931747, 239.21467089653015, 299.0]
# Detected healthy with 0.71 confidence
# Location: [0.0, 102.22597652673721, 242.87512373924255, 299.0]
# Detected healthy with 0.65 confidence
# Location: [0.0, 88.6517259478569, 299.0, 299.0]
# Detected healthy with 0.93 confidence
# Location: [0.0, 92.17126190662384, 299.0, 299.0]
# Detected healthy with 0.96 confidence
# Location: [0.0, 90.29940378665924, 299.0, 299.0]
# Detected healthy with 0.95 confidence
# Location: [0.0, 91.58120030164719, 299.0, 299.0]
# Detected healthy with 0.94 confidence
# Location: [0.0, 92.91386020183563, 299.0, 299.0]
# Detected healthy with 0.96 confidence
# Location: [0.4992952346801758, 91.78007364273071, 299.0, 299.0]
# Detected healthy with 0.86 confidence
# Location: [12.942076086997986, 85.86963778734207, 299.0, 299.0]
# Detected fatty_liver with 0.68 confidence
# Location: [24.465591251850128, 89.11233007907867, 299.0, 299.0]
# Detected healthy with 0.92 confidence
# Location: [59.69837659597397, 91.73587560653687, 299.0, 299.0]
# Detected healthy with 0.98 confidence
# Location: [65.9116759300232, 87.97111183404922, 299.0, 299.0]
# Detected healthy with 0.98 confidence
# Location: [71.41518688201904, 90.12321758270264, 299.0, 299.0]
# Detected healthy with 0.99 confidence
# Location: [77.42624455690384, 91.08546942472458, 299.0, 299.0]
# Detected healthy with 0.96 confidence
# Location: [91.40585172176361, 87.97414153814316, 299.0, 299.0]
# Detected healthy with 0.95 confidence
# Location: [0.0, 105.51095992326736, 202.0716571211815, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 101.45782178640366, 210.89583069086075, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 95.25749671459198, 219.47427743673325, 299.0]
# Detected healthy with 0.97 confidence
# Location: [0.0, 95.19492441415787, 227.998688519001, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 94.70227670669556, 233.86590653657913, 299.0]
# Detected healthy with 0.99 confidence
# Location: [0.0, 96.12942773103714, 235.98958653211594, 299.0]
# Detected healthy with 0.98 confidence
# Location: [0.0, 101.55475449562073, 236.24067771434784, 299.0]
# Detected healthy with 0.92 confidence
# Location: [0.0, 104.6989814043045, 233.71948271989822, 299.0]
# Detected healthy with 0.52 confidence
# Location: [0.0, 89.2021518945694, 299.0, 299.0]
# Visualization saved to liver_analysis_report.png
# ================================================================================
#                     LIVER IMAGING REPORT
# ================================================================================
#
# PATIENT ID: LIV-2025-001
# EXAMINATION DATE: March 09, 2025
# IMAGE ANALYZED: 208_5_3_26_jpg.rf.a1ef0df7cde146acdcb08ff4a8a86c4e.jpg
#
# ================================================================================
# FINDINGS:
# ================================================================================
#
#
# FATTY LIVER:
# - Detected 15 region(s) with average confidence score of 0.67
# - Liver shows increased echogenicity consistent with fatty infiltration. Hepatic vessels appear less prominent with reduced contrast. Findings are consistent with hepatic steatosis.
#
# ================================================================================
# IMPRESSION:
# ================================================================================
#
# 1. FATTY LIVER with moderate confidence (0.67)
#
# ================================================================================
# RECOMMENDATIONS:
# ================================================================================
#
# 1. Recommend clinical correlation with liver function tests.
# 2. Consider dietary modifications and weight management if appropriate.
# 3. Follow-up imaging in 6 months to assess progression.
#
# ================================================================================
#
# Report generated by AI Liver Analysis System
# This is a computer-generated report and requires clinical correlation.
# ================================================================================
